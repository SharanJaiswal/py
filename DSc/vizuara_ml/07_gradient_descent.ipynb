# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Loss function
def f(x):
    return x**2

# %%
# Gradient descent parameters
x_start = 9 # Initial guess
learning_rate = 0.15
n_iterations = 10

# %%
# For storing the iteration steps for visualization
x_steps = [x_start]
y_steps = [f(x_start)]

# %%
# Values for plotting the parabola
x = np.linspace(-10, 10, 400)
y = f(x)

# %%
# first derivative using centered difference
def f_dash(x,f=f,dx=1e-15):
    return (f(x+dx)-f(x-dx))/(2*dx)

# %%
for i in range(n_iterations):
    plt.figure(figsize=(8, 5))
    
    # Plot the parabola
    plt.plot(x, y, label='f(x) = x^2')
    
    # Current position on the parabola
    current_x = x_steps[-1]
    current_y = y_steps[-1]
    
    # Calculate the gradient
    gradient = f_dash(current_x)
    
    # Update the position (gradient descent step)
    next_x = current_x - learning_rate * gradient
    next_y = f(next_x)
    
    # Save the new posotion
    x_steps.append(next_x)
    y_steps.append(next_y)
    
    # Plot the current step path
    plt.scatter(x_steps, y_steps, color='green')
    plt.plot(x_steps, y_steps, linestyle='-', label='Gradient Descent Path')
    
    # Plot the tangent line (derivative at current point)
    tangent_x = np.linspace(current_x - 1, current_x + 1, 10)
    tangent_y = current_y + gradient * (tangent_x - current_x)  # f(x)≈f(x0)+∇f*(x0).T*(x−x 0)  First order taylor expansion around x0
    plt.plot(tangent_x, tangent_y, '--', color='red', linewidth=0.9, label='Tangent at current step')
    
    plt.title(f'Gradient Descent on f(x) = x^2 (Iteration {i+1})')
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.legend()
    plt.grid(True)
